# %% [markdown]
# # Name: Bijay Pareek
#
# # Batch: DS0223
#
# # subject: capstone project sql phase:

# %% [markdown]
# # now i will load the main csv file:

# %%
import pandas as pd

# %%
Real_estate_final_data = pd.read_csv(r"C:/Users/Vijay/Downloads/Real_estate_final_data.csv")
Real_estate_final_data
# Out:
#       Unnamed: 0  SrNo          State_Code     Deposit  \
# 0              0     0          Jollyville   INR 92928
# 1              1     1                  TX   INR 67327
# 2              2     2              Austin  INR 265984
# 3              3     3              Austin  INR 477940
# 4              4     4              Austin  INR 124680
# ...          ...   ...                 ...         ...
# 6273        6273  6273        81547 Munich  INR 131468
# 6274        6274  6274        81825 Munich  INR 115318
# 6275        6275  6275        81373 Munich  INR 136095
# 6276        6276  6276        81677 Munich  INR 190533
# 6277        6277  6277   Lindwurmstraße 60  INR 317555
#
#                      Country       Area no_of_Bathroom no_of_Bedroom  \
# 0                     TX, US   630 Sqft              1             1
# 1                         US   654 Sqft              1             1
# 2              TX 78741, USA  1978 Sqft              2             3
# ...

# %% [markdown]
# # Note: From the Real_estate_final_data csv i will create the 3 csv file for the  sql :

# %%
# Selecting required columns
selected_columns = ['SrNo', 'Address', 'City', 'State_Code', 'Country', 'Rental_price', 'Deposit']
extracted_data = Real_estate_final_data[selected_columns]

# Writing extracted data to CSV file
extracted_data.to_csv('table1.csv')

# Print the extracted data (optional)
print(extracted_data)
# Out:
#       SrNo                                            Address  \
# 0        0                         Austin, Jollyville, TX, US
# 1        1                                     Austin, TX, US
# 2        2         1513 Arcilla Street, Austin, TX 78741, USA
# 3        3             9979 Lavon Bend, Austin, TX 78717, USA
# 4        4       7685 Northcross Drive, Austin, TX 78757, USA
# ...    ...                                                ...
# 6273  6273            Fromundstraße 45, 81547 Munich, Germany
# 6274  6274           Ingeborgstraße 46, 81825 Munich, Germany
# 6275  6275           Alpspitzstraße 12, 81373 Munich, Germany
# 6276  6276          Vogelweidestraße 3, 81677 Munich, Germany
# 6277  6277  Schechinger, Lindwurmstraße 60, 80337 Munich, ...
#
#                        City          State_Code                 Country  \
# 0                    Austin          Jollyville                  TX, US
# 1                    Austin                  TX                      US
# ...

# %%
# Selecting required columns
selected_columns = ['SrNo', 'no_of_Bedroom', 'no_of_Bathroom', 'Area', 'Country', 'Pets_allowed']
extracted_data = Real_estate_final_data[selected_columns]

# Writing extracted data to CSV file
extracted_data.to_csv('table2.csv')

# Print the extracted data (optional)
print(extracted_data)
# Out:
#       SrNo no_of_Bedroom no_of_Bathroom       Area                 Country  \
# 0        0             1              1   630 Sqft                  TX, US
# 1        1             1              1   654 Sqft                      US
# 2        2             3              2  1978 Sqft           TX 78741, USA
# 3        3             5              4  5079 Sqft           TX 78717, USA
# 4        4             1              1   576 Sqft           TX 78757, USA
# ...    ...           ...            ...        ...                     ...
# 6273  6273             1              1   247 Sqft                 Germany
# 6274  6274             2              1   667 Sqft                 Germany
# 6275  6275             1              1   355 Sqft                 Germany
# 6276  6276             2              1   560 Sqft                 Germany
# 6277  6277             4              1   968 Sqft   80337 Munich, Germany
#
#      Pets_allowed
# 0              No
# 1              No
# ...

# %%
Real_estate_final_data.columns
# Out:
# Index(['Unnamed: 0', 'SrNo', 'State_Code', 'Deposit', 'Country', 'Area',
#        'no_of_Bathroom', 'no_of_Bedroom', 'Address', 'Rental_price', 'City',
#        'Air_conditioning ', 'Parking', 'Fireplace', 'Dishwasher',
#        'Hardwood_Floors', 'Roofdeck', 'Storage', 'Washer_Dryer',
#        'Pets_allowed'],
#       dtype='object')

# %%
# Selecting required columns
selected_columns = ['SrNo', 'Washer_Dryer','Parking', 'Fireplace', 'Dishwasher','Hardwood_Floors','Roofdeck','Storage']
extracted_data = Real_estate_final_data[selected_columns]

# Writing extracted data to CSV file
extracted_data.to_csv('table3.csv')

# Print the extracted data (optional)
print(extracted_data)
# Out:
#       SrNo Washer_Dryer Parking Fireplace Dishwasher Hardwood_Floors Roofdeck  \
# 0        0           No      No        No         No              No       No
# 1        1           No      No        No         No              No       No
# 2        2           No      No        No         No              No       No
# 3        3           No      No        No         No              No       No
# 4        4           No      No        No         No              No       No
# ...    ...          ...     ...       ...        ...             ...      ...
# 6273  6273           No      No        No         No              No       No
# 6274  6274           No      No        No         No              No       No
# 6275  6275           No      No        No         No              No       No
# 6276  6276           No      No        No         No              No       No
# 6277  6277           No      No        No         No              No       No
#
#      Storage
# 0         No
# ...
